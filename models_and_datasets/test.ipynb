# %%
from sm_precursor_predictor import get_prediction_and_explanation

prediction, images, plots = get_prediction_and_explanation(smiles="CC(=CCCC(C)(C=C)O)C", threshold=0.20)
# Out:
# /home/jcapela/miniforge3/envs/sm_precursors_predictor_2/lib/python3.10/site-packages/deepmol/compound_featurization/__init__.py:20: UserWarning: Mol2Vec not available. Please install it to use it. (pip install git+https://github.com/samoturk/mol2vec#egg=mol2vec)
#   warnings.warn("Mol2Vec not available. Please install it to use it. "
# /home/jcapela/miniforge3/envs/sm_precursors_predictor_2/lib/python3.10/site-packages/deepmol/compound_featurization/__init__.py:27: UserWarning: DeepChem not available. Please install it to use it.
#   warnings.warn("DeepChem not available. Please install it to use it.")

# %%
import sm_precursor_predictor
sm_precursor_predictor.__version__
# Out:
# '0.0.2'

# %%
from PIL import Image
import io


images[0]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x700 at 0x7FD71020EE60>

# %%
prediction
# Out:
# ['Geranyl diphosphate']
